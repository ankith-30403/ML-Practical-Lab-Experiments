# %% [markdown]
# <a href="https://colab.research.google.com/github/ankith-30403/ML-Practical-Lab-Experiments/blob/main/Week2_Skill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("student_performance_dataset.csv")
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(6,4))

sns.countplot(data=df, x="gender")

plt.title("Student Count by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.show()

plt.figure(figsize=(6,4))

plt.hist(df["final_exam_score"].dropna(),
         bins=15,
         color="skyblue",
         edgecolor="black")

plt.title("Final Exam Score Distribution")
plt.xlabel("Final Exam Score")
plt.ylabel("Frequency")

plt.show()

plt.figure(figsize=(6,5))

numeric_df = df.select_dtypes(include="number")

corr_matrix = numeric_df.corr()

sns.heatmap(corr_matrix,
            annot=True,
            cmap="coolwarm",
            fmt=".2f")

plt.title("Correlation Heatmap")

plt.show()
